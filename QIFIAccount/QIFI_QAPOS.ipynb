# %%
# test QAPositions

# %%
from QUANTAXIS.QAMarket.QAPosition import QA_Position

# %%
pos = QA_Position(code = 'RB2001')

# %%
pos.message
# Out:
# {'code': 'RB2001',
#  'instrument_id': 'RB2001',
#  'user_id': 'quantaxis',
#  'portfolio_cookie': 'portfolio',
#  'username': 'quantaxis',
#  'position_id': 'b9f854f8-6046-4db6-8503-318feef0d1d7',
#  'account_cookie': 'quantaxis',
#  'frozen': {},
#  'name': None,
#  'spms_id': None,
#  'oms_id': None,
#  'market_type': 'future_cn',
#  'exchange_id': None,
#  'moneypreset': 100000,
#  'moneypresetLeft': 100000,
#  'lastupdatetime': '',
#  'volume_long_today': 0,
#  'volume_long_his': 0,
#  'volume_long': 0,
#  'volume_short_today': 0,
#  'volume_short_his': 0,
#  'volume_short': 0,
#  'volume_long_frozen_today': 0,
#  'volume_long_frozen_his': 0,
#  'volume_long_frozen': 0,
#  'volume_short_frozen_today': 0,
#  'volume_short_frozen_his': 0,
#  'volume_short_frozen': 0,
#  'margin_long': 0,
#  'margin_short': 0,
#  'margin': 0,
#  'position_price_long': 0,
#  'position_cost_long': 0,
#  'position_price_short': 0,
#  'position_cost_short': 0,
#  'open_price_long': 0,
#  'open_cost_long': 0,
#  'open_price_short': 0,
#  'open_cost_short': 0,
#  'trades': [],
#  'orders': {},
#  'last_price': 0,
#  'float_profit_long': 0,
#  'float_profit_short': 0,
#  'float_profit': 0,
#  'position_profit_long': 0,
#  'position_profit_short': 0,
#  'position_profit': 0}

# %%
pos.update_pos(3000, amount=1,towards=2)

# %%
pos.curpos
# Out:
# {'volume_long': 1,
#  'volume_short': 0,
#  'volume_long_frozen': 0,
#  'volume_short_frozen': 0}

# %%
pos.static_message
# Out:
# {'code': 'RB2001',
#  'instrument_id': 'RB2001',
#  'user_id': 'quantaxis',
#  'portfolio_cookie': 'portfolio',
#  'username': 'quantaxis',
#  'position_id': 'b9f854f8-6046-4db6-8503-318feef0d1d7',
#  'account_cookie': 'quantaxis',
#  'frozen': {},
#  'name': None,
#  'spms_id': None,
#  'oms_id': None,
#  'market_type': 'future_cn',
#  'exchange_id': None,
#  'moneypreset': 100000,
#  'moneypresetLeft': 97300.0,
#  'lastupdatetime': '',
#  'volume_long_today': 1,
#  'volume_long_his': 0,
#  'volume_long': 1,
#  'volume_short_today': 0,
#  'volume_short_his': 0,
#  'volume_short': 0,
#  'volume_long_frozen_today': 0,
#  'volume_long_frozen_his': 0,
#  'volume_long_frozen': 0,
#  'volume_short_frozen_today': 0,
#  'volume_short_frozen_his': 0,
#  'volume_short_frozen': 0,
#  'margin_long': 2700.0,
#  'margin_short': 0,
#  'margin': 2700.0,
#  'position_price_long': 3000.0,
#  'position_cost_long': 30000.0,
#  'position_price_short': 0,
#  'position_cost_short': 0,
#  'open_price_long': 3000.0,
#  'open_cost_long': 30000.0,
#  'open_price_short': 0,
#  'open_cost_short': 0,
#  'trades': [],
#  'orders': {}}

# %%
pos.message
# Out:
# {'code': 'RB2001',
#  'instrument_id': 'RB2001',
#  'user_id': 'quantaxis',
#  'portfolio_cookie': 'portfolio',
#  'username': 'quantaxis',
#  'position_id': 'b9f854f8-6046-4db6-8503-318feef0d1d7',
#  'account_cookie': 'quantaxis',
#  'frozen': {},
#  'name': None,
#  'spms_id': None,
#  'oms_id': None,
#  'market_type': 'future_cn',
#  'exchange_id': None,
#  'moneypreset': 100000,
#  'moneypresetLeft': 97300.0,
#  'lastupdatetime': '',
#  'volume_long_today': 1,
#  'volume_long_his': 0,
#  'volume_long': 1,
#  'volume_short_today': 0,
#  'volume_short_his': 0,
#  'volume_short': 0,
#  'volume_long_frozen_today': 0,
#  'volume_long_frozen_his': 0,
#  'volume_long_frozen': 0,
#  'volume_short_frozen_today': 0,
#  'volume_short_frozen_his': 0,
#  'volume_short_frozen': 0,
#  'margin_long': 2700.0,
#  'margin_short': 0,
#  'margin': 2700.0,
#  'position_price_long': 3000.0,
#  'position_cost_long': 30000.0,
#  'position_price_short': 0,
#  'position_cost_short': 0,
#  'open_price_long': 3000.0,
#  'open_cost_long': 30000.0,
#  'open_price_short': 0,
#  'open_cost_short': 0,
#  'trades': [],
#  'orders': {},
#  'last_price': 3000,
#  'float_profit_long': 0.0,
#  'float_profit_short': 0,
#  'float_profit': 0.0,
#  'position_profit_long': 0.0,
#  'position_profit_short': 0,
#  'position_profit': 0.0}

# %%
pos.on_pirce_change(3100)

# %%
pos.message
# Out:
# {'code': 'RB2001',
#  'instrument_id': 'RB2001',
#  'user_id': 'quantaxis',
#  'portfolio_cookie': 'portfolio',
#  'username': 'quantaxis',
#  'position_id': 'b9f854f8-6046-4db6-8503-318feef0d1d7',
#  'account_cookie': 'quantaxis',
#  'frozen': {},
#  'name': None,
#  'spms_id': None,
#  'oms_id': None,
#  'market_type': 'future_cn',
#  'exchange_id': None,
#  'moneypreset': 100000,
#  'moneypresetLeft': 97300.0,
#  'lastupdatetime': '',
#  'volume_long_today': 1,
#  'volume_long_his': 0,
#  'volume_long': 1,
#  'volume_short_today': 0,
#  'volume_short_his': 0,
#  'volume_short': 0,
#  'volume_long_frozen_today': 0,
#  'volume_long_frozen_his': 0,
#  'volume_long_frozen': 0,
#  'volume_short_frozen_today': 0,
#  'volume_short_frozen_his': 0,
#  'volume_short_frozen': 0,
#  'margin_long': 2700.0,
#  'margin_short': 0,
#  'margin': 2700.0,
#  'position_price_long': 3000.0,
#  'position_cost_long': 30000.0,
#  'position_price_short': 0,
#  'position_cost_short': 0,
#  'open_price_long': 3000.0,
#  'open_cost_long': 30000.0,
#  'open_price_short': 0,
#  'open_cost_short': 0,
#  'trades': [],
#  'orders': {},
#  'last_price': 3100,
#  'float_profit_long': 1000.0,
#  'float_profit_short': 0,
#  'float_profit': 1000.0,
#  'position_profit_long': 1000.0,
#  'position_profit_short': 0,
#  'position_profit': 1000.0}

# %%
pos1 = QA_Position(code='000001')

# %%
pos1.message
# Out:
# {'code': '000001',
#  'instrument_id': '000001',
#  'user_id': 'quantaxis',
#  'portfolio_cookie': 'portfolio',
#  'username': 'quantaxis',
#  'position_id': 'a2614426-6b91-4127-968d-a1929a9cb6e4',
#  'account_cookie': 'quantaxis',
#  'frozen': {},
#  'name': None,
#  'spms_id': None,
#  'oms_id': None,
#  'market_type': 'stock_cn',
#  'exchange_id': None,
#  'moneypreset': 100000,
#  'moneypresetLeft': 100000,
#  'lastupdatetime': '',
#  'volume_long_today': 0,
#  'volume_long_his': 0,
#  'volume_long': 0,
#  'volume_short_today': 0,
#  'volume_short_his': 0,
#  'volume_short': 0,
#  'volume_long_frozen_today': 0,
#  'volume_long_frozen_his': 0,
#  'volume_long_frozen': 0,
#  'volume_short_frozen_today': 0,
#  'volume_short_frozen_his': 0,
#  'volume_short_frozen': 0,
#  'margin_long': 0,
#  'margin_short': 0,
#  'margin': 0,
#  'position_price_long': 0,
#  'position_cost_long': 0,
#  'position_price_short': 0,
#  'position_cost_short': 0,
#  'open_price_long': 0,
#  'open_cost_long': 0,
#  'open_price_short': 0,
#  'open_cost_short': 0,
#  'trades': [],
#  'orders': {},
#  'last_price': 0,
#  'float_profit_long': 0,
#  'float_profit_short': 0,
#  'float_profit': 0,
#  'position_profit_long': 0,
#  'position_profit_short': 0,
#  'position_profit': 0}

# %%
from QIFIAccount import QIFI_Account, ORDER_DIRECTION, uuid

# %%
acc = QIFI_Account("x1", "x1")
acc.initial()
import pprint
pprint.pprint(acc.message)

r = acc.send_order('RB2001', 10, 5000, ORDER_DIRECTION.BUY_OPEN)
print(r)

acc.receive_deal(r['instrument_id'], 4500, r['volume'], r['towards'],
                 acc.dtstr, order_id=r['order_id'], trade_id=str(uuid.uuid4()))
import pprint
pprint.pprint(acc.message)
# Out:
# {'account_cookie': 'b34fab49-5638-4186-8cde-8b2b925baa8d',
#  'accounts': {'WithdrawQuota': 0,
#               'available': 1000000,
#               'balance': 0,
#               'close_profit': 0,
#               'commission': 0,
#               'currency': 'CNY',
#               'deposit': 1000000,
#               'float_profit': None,
#               'frozen_commission': 0.0,
#               'frozen_margin': 0.0,
#               'frozen_premium': 0.0,
#               'margin': 0,
#               'position_profit': None,
#               'pre_balance': 0,
#               'premium': None,
#               'risk_ratio': 0.0,
#               'static_balance': 0,
#               'user_id': 'b34fab49-5638-4186-8cde-8b2b925baa8d',
#               'withdraw': 0},
#  'bank_password': '',
#  'bankid': 'QASIM',
#  'bankname': 'QASIMBank',
#  'banks': {'QASIM': {'bank_account': '',
#                      'fetch_amount': 0.0,
#                      'id': 'QASIM',
#                      'name': 'QASIMBank',
#                      'qry_count': 0}},
#  'broker_name': 'QUANTAXIS',
#  'capital_password': '',
#  'events': {'2019-10-07 15:16:45.798076': '转账成功 1000000'},
#  'investor_name': '',
#  'model': 'SIM',
#  'money': 1000000,
#  'orders': {},
#  'password': '55f10e35-eb34-489c-ba8d-6d1309cb5437',
#  'ping_gap': 5,
#  'portfolio': '',
#  'positions': {},
#  'pub_host': '',
#  'settlement': {},
#  'sourceid': 'QIFI_Account',
#  'status': 200,
#  'taskid': '',
#  'trade_host': '',
#  'trades': {},
#  'trading_day': '2019-10-07',
#  'transfers': {'0': {'amount': 1000000,
#                      'currency': 'CNY',
#                      'datetime': 433241234123,
#                      'error_id': 0,
#                      'error_msg': '成功'}},
#  'updatetime': '',
#  'wsuri': 'ws://www.yutiansut.com:7988'}
# {'account_cookie': 'b34fab49-5638-4186-8cde-8b2b925baa8d', 'user_id': 'b34fab49-5638-4186-8cde-8b2b925baa8d', 'instrument_id': 'RB2001', 'towards': 2, 'exchange_id': 'SHFE', 'order_time': '2019-10-07 15:16:45.928159', 'volume': 10.0, 'price': 5000.0, 'order_id': '07b8b37a-1153-4ff6-8a77-51c2d5265b9e', 'seqno': 1, 'direction': 'BUY', 'offset': 'OPEN', 'volume_orign': 10.0, 'price_type': 'LIMIT', 'limit_price': 5000.0, 'time_condition': 'GFD', 'volume_condition': 'ANY', 'insert_date_time': '2019-10-07 15:16:45.928159', 'exchange_order_id': 'a3067a7f-2f45-4053-9105-eae174e8a5b9', 'status': 100, 'volume_left': 10.0, 'last_msg': '已报'}
# {'account_cookie': 'b34fab49-5638-4186-8cde-8b2b925baa8d',
#  'accounts': {'WithdrawQuota': 0,
#               'available': 955000.0,
#               'balance': 0,
#               'close_profit': 0,
#               'commission': 0,
#               'currency': 'CNY',
#               'deposit': 1000000,
#               'float_profit': None,
#               'frozen_commission': 0.0,
#               'frozen_margin': 0.0,
#               'frozen_premium': 0.0,
#               'margin': 40500.0,
#               'position_profit': None,
#               'pre_balance': 0,
#               'premium': None,
#               'risk_ratio': 0.0,
#               'static_balance': 0,
#               'user_id': 'b34fab49-5638-4186-8cde-8b2b925baa8d',
#               'withdraw': 0},
#  'bank_password': '',
#  'bankid': 'QASIM',
#  'bankname': 'QASIMBank',
#  'banks': {'QASIM': {'bank_account': '',
#                      'fetch_amount': 0.0,
#                      'id': 'QASIM',
#                      'name': 'QASIMBank',
#                      'qry_count': 0}},
#  'broker_name': 'QUANTAXIS',
#  'capital_password': '',
#  'events': {'2019-10-07 15:16:45.798076': '转账成功 1000000',
#             '2019-10-07 15:16:45.929185': '全部成交 '
#                                           '07b8b37a-1153-4ff6-8a77-51c2d5265b9e'},
#  'investor_name': '',
#  'model': 'SIM',
#  'money': 955000.0,
#  'orders': {'07b8b37a-1153-4ff6-8a77-51c2d5265b9e': {'account_cookie': 'b34fab49-5638-4186-8cde-8b2b925baa8d',
#                                                      'direction': 'BUY',
#                                                      'exchange_id': 'SHFE',
#                                                      'exchange_order_id': 'a3067a7f-2f45-4053-9105-eae174e8a5b9',
#                                                      'insert_date_time': '2019-10-07 '
#                                                                          '15:16:45.928159',
#                                                      'instrument_id': 'RB2001',
#                                                      'last_msg': '全部成交',
#                                                      'limit_price': 5000.0,
#                                                      'offset': 'OPEN',
#                                                      'order_id': '07b8b37a-1153-4ff6-8a77-51c2d5265b9e',
#                                                      'order_time': '2019-10-07 '
#                                                                    '15:16:45.928159',
#                                                      'price': 5000.0,
#                                                      'price_type': 'LIMIT',
#                                                      'seqno': 1,
#                                                      'status': 300,
#                                                      'time_condition': 'GFD',
#                                                      'towards': 2,
#                                                      'user_id': 'b34fab49-5638-4186-8cde-8b2b925baa8d',
#                                                      'volume': 10.0,
#                                                      'volume_condition': 'ANY',
#                                                      'volume_left': 0.0,
#                                                      'volume_orign': 10.0}},
#  'password': '55f10e35-eb34-489c-ba8d-6d1309cb5437',
#  'ping_gap': 5,
#  'portfolio': '',
#  'positions': {'RB2001': {'account_cookie': 'quantaxis',
#                           'code': 'RB2001',
#                           'exchange_id': None,
#                           'float_profit': 0.0,
#                           'float_profit_long': 0.0,
#                           'float_profit_short': 0,
#                           'frozen': {},
#                           'instrument_id': 'RB2001',
#                           'last_price': 4500,
#                           'lastupdatetime': '',
#                           'margin': 40500.0,
#                           'margin_long': 40500.0,
#                           'margin_short': 0,
#                           'market_type': 'future_cn',
#                           'moneypreset': 100000,
#                           'moneypresetLeft': 59500.0,
#                           'name': None,
#                           'oms_id': None,
#                           'open_cost_long': 450000.0,
#                           'open_cost_short': 0,
#                           'open_price_long': 4500.0,
#                           'open_price_short': 0,
#                           'orders': {},
#                           'portfolio_cookie': 'portfolio',
#                           'position_cost_long': 450000.0,
#                           'position_cost_short': 0,
#                           'position_id': 'a1a20b80-4dad-425c-ac78-812aa2e5e289',
#                           'position_price_long': 4500.0,
#                           'position_price_short': 0,
#                           'position_profit': 0.0,
#                           'position_profit_long': 0.0,
#                           'position_profit_short': 0,
#                           'spms_id': None,
#                           'trades': [],
#                           'user_id': 'quantaxis',
#                           'username': 'quantaxis',
#                           'volume_long': 10.0,
#                           'volume_long_frozen': 0,
#                           'volume_long_frozen_his': 0,
#                           'volume_long_frozen_today': 0,
#                           'volume_long_his': 0,
#                           'volume_long_today': 10.0,
#                           'volume_short': 0,
#                           'volume_short_frozen': 0,
#                           'volume_short_frozen_his': 0,
#                           'volume_short_frozen_today': 0,
#                           'volume_short_his': 0,
#                           'volume_short_today': 0}},
#  'pub_host': '',
#  'settlement': {},
#  'sourceid': 'QIFI_Account',
#  'status': 200,
#  'taskid': '',
#  'trade_host': '',
#  'trades': {'edb95708-001a-4b86-a80a-d28374df5190': {'direction': 'BUY',
#                                                      'exchange_id': 'SHFE',
#                                                      'exchange_trade_id': 'edb95708-001a-4b86-a80a-d28374df5190',
#                                                      'instrument_id': 'RB2001',
#                                                      'offset': 'OPEN',
#                                                      'order_id': '07b8b37a-1153-4ff6-8a77-51c2d5265b9e',
#                                                      'price': 4500,
#                                                      'seqno': 2,
#                                                      'trade_date_time': '2019-10-07 '
#                                                                         '15:16:45.929185',
#                                                      'trade_id': 'edb95708-001a-4b86-a80a-d28374df5190',
#                                                      'user_id': 'b34fab49-5638-4186-8cde-8b2b925baa8d',
#                                                      'volume': 10.0}},
#  'trading_day': '2019-10-07',
#  'transfers': {'0': {'amount': 1000000,
#                      'currency': 'CNY',
#                      'datetime': 433241234123,
#                      'error_id': 0,
#                      'error_msg': '成功'}},
#  'updatetime': '',
#  'wsuri': 'ws://www.yutiansut.com:7988'}
